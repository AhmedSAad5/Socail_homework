# %%
import json
search_tweets = json.load(open('C:/Users/Microsoft/Desktop/FirstCourseNetworkScience-master/datasets/science_tweets.json'))

# %%
from twython import Twython
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/438245701.py in <module>
# ----> 1 from twython import Twython
#
# ModuleNotFoundError: No module named 'twython'

# %%
API_KEY = 'xxxxxxxxxxxx'
API_SECRET_KEY = 'xxxxxxxxxxxxxxxxxxxxxxxxx'

twitter = Twython(API_KEY, API_SECRET_KEY)

authentication_tokens = twitter.get_authentication_tokens()
print(authentication_tokens['auth_url'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/1156529859.py in <module>
#       2 API_SECRET_KEY = 'xxxxxxxxxxxxxxxxxxxxxxxxx'
#       3
# ----> 4 twitter = Twython(API_KEY, API_SECRET_KEY)
#       5
#       6 authentication_tokens = twitter.get_authentication_tokens()
#
# NameError: name 'Twython' is not defined

# %%
VERIFIER = '0000000'

twitter = Twython(API_KEY, API_SECRET_KEY,
                  authentication_tokens['oauth_token'],
                  authentication_tokens['oauth_token_secret'])

authorized_tokens = twitter.get_authorized_tokens(VERIFIER)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/79339805.py in <module>
#       1 VERIFIER = '0000000'
#       2
# ----> 3 twitter = Twython(API_KEY, API_SECRET_KEY,
#       4                   authentication_tokens['oauth_token'],
#       5                   authentication_tokens['oauth_token_secret'])
#
# NameError: name 'Twython' is not defined

# %%
twitter = Twython(API_KEY, API_SECRET_KEY,
                  authorized_tokens['oauth_token'],
                  authorized_tokens['oauth_token_secret'])

twitter.verify_credentials()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/3514727110.py in <module>
# ----> 1 twitter = Twython(API_KEY, API_SECRET_KEY,
#       2                   authorized_tokens['oauth_token'],
#       3                   authorized_tokens['oauth_token_secret'])
#       4
#       5 twitter.verify_credentials()
#
# NameError: name 'Twython' is not defined

# %%
user = twitter.show_user(screen_name='OSoMe_IU')
user
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/535335268.py in <module>
# ----> 1 user = twitter.show_user(screen_name='OSoMe_IU')
#       2 user
#
# NameError: name 'twitter' is not defined

# %%
user['screen_name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/1598639905.py in <module>
# ----> 1 user['screen_name']
#
# NameError: name 'user' is not defined

# %%
print("""
Twitter user @{screen_name}
has {followers_count} followers,
follows {friends_count} users,
and has tweeted {statuses_count} times.
""".format(**user))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/3369442860.py in <module>
#       4 follows {friends_count} users,
#       5 and has tweeted {statuses_count} times.
# ----> 6 """.format(**user))
#
# NameError: name 'user' is not defined

# %%
most_recent_tweet = user['status']
most_recent_tweet
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/770698693.py in <module>
# ----> 1 most_recent_tweet = user['status']
#       2 most_recent_tweet
#
# NameError: name 'user' is not defined

# %%
most_recent_tweet['text']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/2342868158.py in <module>
# ----> 1 most_recent_tweet['text']
#
# NameError: name 'most_recent_tweet' is not defined

# %%
most_recent_tweet['entities']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/186879404.py in <module>
# ----> 1 most_recent_tweet['entities']
#
# NameError: name 'most_recent_tweet' is not defined

# %%
most_recent_tweet['entities']['user_mentions']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/3106751867.py in <module>
# ----> 1 most_recent_tweet['entities']['user_mentions']
#
# NameError: name 'most_recent_tweet' is not defined

# %%
search_response = twitter.search(q='#science', count=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/846397274.py in <module>
# ----> 1 search_response = twitter.search(q='#science', count=100)
#
# NameError: name 'twitter' is not defined

# %%
search_tweets = search_response['statuses']
tweet = search_tweets[0]
tweet
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/4067461691.py in <module>
# ----> 1 search_tweets = search_response['statuses']
#       2 tweet = search_tweets[0]
#       3 tweet
#
# NameError: name 'search_response' is not defined

# %%
tweet['user']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/72725268.py in <module>
# ----> 1 tweet['user']
#
# NameError: name 'tweet' is not defined

# %%
search_response = twitter.search(q='#science', count=1000)
len(search_response['statuses'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/1956577397.py in <module>
# ----> 1 search_response = twitter.search(q='#science', count=1000)
#       2 len(search_response['statuses'])
#
# NameError: name 'twitter' is not defined

# %%
import itertools

NUM_TWEETS_TO_FETCH = 1000

cursor = twitter.cursor(twitter.search, q='#science', count=100, result_type='mixed')
search_tweets = list(itertools.islice(cursor, NUM_TWEETS_TO_FETCH))
len(search_tweets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/2552216322.py in <module>
#       3 NUM_TWEETS_TO_FETCH = 1000
#       4
# ----> 5 cursor = twitter.cursor(twitter.search, q='#science', count=100, result_type='mixed')
#       6 search_tweets = list(itertools.islice(cursor, NUM_TWEETS_TO_FETCH))
#       7 len(search_tweets)
#
# NameError: name 'twitter' is not defined

# %%
type(cursor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/760653937.py in <module>
# ----> 1 type(cursor)
#
# NameError: name 'cursor' is not defined

# %%
twitter.get_application_rate_limit_status()['resources']['search']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/3555470843.py in <module>
# ----> 1 twitter.get_application_rate_limit_status()['resources']['search']
#
# NameError: name 'twitter' is not defined

# %%
import networkx as nx

D = nx.DiGraph()

publisher = twitter.show_user(screen_name='CambridgeUP')
author = twitter.show_user(screen_name='osome_iu')

D.add_edge(publisher['screen_name'], author['screen_name'], weight=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/2537753880.py in <module>
#       3 D = nx.DiGraph()
#       4
# ----> 5 publisher = twitter.show_user(screen_name='CambridgeUP')
#       6 author = twitter.show_user(screen_name='osome_iu')
#       7
#
# NameError: name 'twitter' is not defined

# %%
list(D.edges(data=True))
# Out:
# []

# %%
import itertools

NUM_TWEETS_TO_FETCH = 1000

cursor = twitter.cursor(twitter.search, q='#science', count=100, result_type='mixed')
search_tweets = list(itertools.islice(cursor, NUM_TWEETS_TO_FETCH))
len(search_tweets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/2552216322.py in <module>
#       3 NUM_TWEETS_TO_FETCH = 1000
#       4
# ----> 5 cursor = twitter.cursor(twitter.search, q='#science', count=100, result_type='mixed')
#       6 search_tweets = list(itertools.islice(cursor, NUM_TWEETS_TO_FETCH))
#       7 len(search_tweets)
#
# NameError: name 'twitter' is not defined

# %%
retweets = []
for tweet in search_tweets:
    if 'retweeted_status' in tweet:
        retweets.append(tweet)
len(retweets)
# Out:
# 511

# %%
import networkx as nx

D = nx.DiGraph()

for retweet in retweets:
    retweeted_status = retweet['retweeted_status']
    retweeted_sn = retweeted_status['user']['screen_name']
    retweeter_sn = retweet['user']['screen_name']
    

    if D.has_edge(retweeted_sn, retweeter_sn):
        D.edges[retweeted_sn, retweeter_sn]['weight'] += 1
    else:
        D.add_edge(retweeted_sn, retweeter_sn, weight=1)

# %%
max(D.nodes, key=D.out_degree)
# Out:
# 'AntonioParis'

# %%
from operator import itemgetter

sorted(D.out_degree(), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('AntonioParis', 49),
#  ('JaviTannhauser', 15),
#  ('illucifer', 11),
#  ('maximaxoo', 10),
#  ('BetteAStevens', 8)]

# %%
sorted(D.out_degree(weight='weight'), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('AntonioParis', 50),
#  ('JaviTannhauser', 15),
#  ('illucifer', 11),
#  ('maximaxoo', 10),
#  ('AgiwaldW', 9)]

# %%
sorted(D.in_degree(weight='weight'), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('Tess_blue815', 8),
#  ('CastevenLimKHJB', 5),
#  ('Emc2CoinHQ', 3),
#  ('cosmicscape', 3),
#  ('jhainley1', 3)]

# %%
nx.is_weakly_connected(D)
# Out:
# False

# %%
nx.number_weakly_connected_components(D)
# Out:
# 246

# %%
node_sizes = [D.out_degree(n, weight='weight') * 50 for n in D.nodes]

# %matplotlib inline
nx.draw(D, node_size=node_sizes)

# %%
import itertools

NUM_TWEETS_TO_FETCH = 1000

cursor = twitter.cursor(twitter.search, q='#science', count=100, result_type='mixed')
search_tweets = list(itertools.islice(cursor, NUM_TWEETS_TO_FETCH))
len(search_tweets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11316/2552216322.py in <module>
#       3 NUM_TWEETS_TO_FETCH = 1000
#       4
# ----> 5 cursor = twitter.cursor(twitter.search, q='#science', count=100, result_type='mixed')
#       6 search_tweets = list(itertools.islice(cursor, NUM_TWEETS_TO_FETCH))
#       7 len(search_tweets)
#
# NameError: name 'twitter' is not defined

# %%
import networkx as nx

D = nx.DiGraph()

for tweet in search_tweets:
    tweet_sn = tweet['user']['screen_name']
    for user_mention in tweet['entities']['user_mentions']:
        mentioned_sn = user_mention['screen_name']
        
        my_edge = (tweet_sn, mentioned_sn)
        if D.has_edge(*my_edge):
            D.edges[my_edge]['weight'] += 1
        else:
            D.add_edge(*my_edge, weight=1)

# %%
max(D.nodes, key=D.in_degree)
# Out:
# 'AntonioParis'

# %%
from operator import itemgetter

sorted(D.in_degree(), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('AntonioParis', 49),
#  ('astronomy', 15),
#  ('JaviTannhauser', 15),
#  ('ChefBoyardee', 12),
#  ('illucifer', 11)]

# %%
sorted(D.in_degree(weight='weight'), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('AntonioParis', 50),
#  ('astronomy', 15),
#  ('JaviTannhauser', 15),
#  ('UN', 14),
#  ('ChefBoyardee', 13)]

# %%
sorted(D.out_degree(weight='weight'), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('51Prentice', 11),
#  ('Tess_blue815', 8),
#  ('plantletculture', 6),
#  ('Matt_Lucy_JDS', 5),
#  ('CastevenLimKHJB', 5)]

# %%
nx.is_weakly_connected(D)
# Out:
# False

# %%
nx.number_weakly_connected_components(D)
# Out:
# 300

# %%
node_sizes = [D.in_degree(n, weight='weight') * 50 for n in D.nodes]

# %matplotlib inline
nx.draw(D, node_size=node_sizes)
